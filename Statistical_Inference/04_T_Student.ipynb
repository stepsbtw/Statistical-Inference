# %% [markdown]
# <a href="https://colab.research.google.com/github/stepsbtw/Statistics-Inference-AI-and-ML/blob/main/Statistical_Inference/04_T_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Distribuição t de Student
#
# Para estimar μ e ρ com amostras pequenas - tamanho (n < 30) -, usamos esta distribuição t de student.
#
# - A forma de sua função de densidade aproxima a NORMAL, dado um parâmetro 𝑉 (graus de liberdade). Na prática utilizamos:
#
# 𝑉 = n-1
#
# - A distribuição t é a **Distribuição Amostral de T**, quando v = n-1
#
# T definida como:
#
#   ![image.png](data:image/png;base64,...)
# ou ![image.png](data:image/png;base64,...)
#
# - T segue mesmo a distribuição T de student?
#
# **Com n-1 graus de liberdade, temos:**
#
#   ![image.png](data:image/png;base64,...)
#
# - **T SÓ SEGUE A DISTRIBUIÇÃO t de Student QUANDO V = N-1 (Graus de Liberdade)**
#
# Utilizando a função gama, essa f(t) modela uma variável que segue a distribuição t.
#
# Portanto a quantidade V (graus de liberdade) é um **Parâmetro da Distribuição**.

# %% [markdown]
# ### Semelhança com a **Normal**:
#
#   ![image.png](data:image/png;base64,...)
#
# - Importante notar que a variável Z segue por definição a **DISTRIBUIÇÃO NORMAL PADRÃO** (se σ=1), no entanto T **NÃO SEGUE**
#
# Isso se deve ao fato de que utilizamos s (o desvio padrão amostral) em uma pequena amostra.
#
# - Portanto a distribuição t leva em consideração esse maior grau de incerteza que s apresenta em relação a σ.
#
# No lim n->inf, com a quantidade de graus de liberdade v = n-1,
# - A distribuição t de Student é **IGUAL** a distribuição **NORMAL PADRÃO**

# %% [markdown]
# ## Graus de liberdade
# - Define o quão espessa serão as caudas da distribuição, deste modo funcionando como uma espécie de desvio padrão na NORMAL, tendo um efeito de **achatamento** porém as probabilidades são mais **espalhadas** para as caudas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Função de Densidade de Probabilidade
#
# ![image.png](data:image/png;base64,...)
#
# - Comparando com a NORMAL
#
# ![image.png](data:image/png;base64,...)
#
# - Normal padrão:
#
# ![image.png](data:image/png;base64,...)
